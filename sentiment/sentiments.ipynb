# %%
import pandas as pd
import numpy as np
import re
import transformers
from transformers import pipeline
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
data = pd.read_csv("book_reviews_sample.csv")
data.head()
# Out:
#    index                                         reviewText  rating
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1

# %%
data["reviewText"][0]
# Out:
# 'Clean and funny. A bit busy with all the different plots going on. But overall a good read. Bye now.'

# %%
data["reviewText_cleaned"] = data["reviewText"].apply(lambda x: re.sub(r"[^\w\s]", "", x.lower()))
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                   reviewText_cleaned
# 0  clean and funny a bit busy with all the differ...
# 1  alex a sexy hot cop and the phd candidate what...
# 2  good thing that this is a free story i read it...
# 3  action action action equipment keeps getting b...
# 4  this was hands down the worse book i have ever...

# %%
vader_sentiment = SentimentIntensityAnalyzer()
data["vader_sentiment"] = data["reviewText_cleaned"].apply(lambda x: vader_sentiment.polarity_scores(x)["compound"])
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                   reviewText_cleaned  vader_sentiment
# 0  clean and funny a bit busy with all the differ...           0.7684
# 1  alex a sexy hot cop and the phd candidate what...           0.9325
# 2  good thing that this is a free story i read it...           0.6740
# 3  action action action equipment keeps getting b...           0.6652
# 4  this was hands down the worse book i have ever...          -0.4767

# %%
bins = [-1, -0.1, 0.1, 1]
labels = ["negative", "neutral", "positive"]
data["vader_sentiment_label"] = pd.cut(data["vader_sentiment"], bins=bins, labels=labels)
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                   reviewText_cleaned  vader_sentiment  \
# 0  clean and funny a bit busy with all the differ...           0.7684
# 1  alex a sexy hot cop and the phd candidate what...           0.9325
# 2  good thing that this is a free story i read it...           0.6740
# 3  action action action equipment keeps getting b...           0.6652
# 4  this was hands down the worse book i have ever...          -0.4767
#
#   vader_sentiment_label
# 0              positive
# 1              positive
# 2              positive
# 3              positive
# 4              negative

# %%
data["vader_sentiment_label"].value_counts()
# Out:
# vader_sentiment_label
# positive    68
# negative    19
# neutral     13
# Name: count, dtype: int64

# %%
data["vader_sentiment_label"].value_counts().plot(kind="bar", title="Vader Sentiment Distribution")
# Out:
# <Axes: title={'center': 'Vader Sentiment Distribution'}, xlabel='vader_sentiment_label'>

# %%
# Using a transformer to analyse the sentiment on the book reviews
transformer_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0

# %%
transformer_labels = []

for review in data["reviewText_cleaned"]:
    sentiment_list = transformer_pipeline(review)
    sentiment_label = [ sentiment["label"] for sentiment in sentiment_list ]
    print(f"Review: {review}\nSentiment: {sentiment_label}\n")
    transformer_labels.append(sentiment_label)
# Out:
# Review: clean and funny a bit busy with all the different plots going on but overall a good read bye now
# Sentiment: ['POSITIVE']
#
# Review: alex a sexy hot cop and the phd candidate what a match that makes for a great fun and exciting book
# Sentiment: ['POSITIVE']
#
# Review: good thing that this is a free story i read it a few years ago and it is not worth the time
# Sentiment: ['NEGATIVE']
#
# Review: action action action equipment keeps getting blown up but the heroes live on and on
# Sentiment: ['NEGATIVE']
#
# Review: this was hands down the worse book i have ever read and trst me that says alot
# Sentiment: ['NEGATIVE']
#
# Review: great book packed full with fast cars  crazy hot men and danger and oh yes great sex
# Sentiment: ['POSITIVE']
#
# Review: i enjoyed the readers digest very much if i could figure out how to get it on my kinkle i would
# Sentiment: ['POSITIVE']
#
# Review: this series has been good and i look forward to any more she writes she has a great way with words
# Sentiment: ['POSITIVE']
#
# Review: i just could not get into this booki all ways read a book when i start it this one i could not
# Sentiment: ['NEGATIVE']
#
# Review: it was good to see where dan and elle was and that they was still together and so much in love
# Sentiment: ['POSITIVE']
#
# Review: let down did not think it was worth the money spent at all nothing in it seemed of real value
# Sentiment: ['NEGATIVE']
#
# Review: i did not cared for this ebook i did not finish this ebook i would not recommend it to others
# Sentiment: ['NEGATIVE']
#
# Review: this was to short i will not be telling my friends bout it i did not like the topic of the story
# Sentiment: ['NEGATIVE']
#
# Review: wings of the night part 1 so happy to have a chance to revisit this series  cannot wait for more
# Sentiment: ['POSITIVE']
#
# Review: not my cup of tea  i could not follow plot  no happy ever after tale  not my cup of tea
# Sentiment: ['NEGATIVE']
#
# Review: a typical romance but with a twist  not great
# Sentiment: ['NEGATIVE']
#
# Review: this book for me was okay it was quite stalling at times i really had to force myself to finish it
# Sentiment: ['NEGATIVE']
#
# Review: man i wish these series were longer i thought the book was really good i was so into this book
# Sentiment: ['NEGATIVE']
#
# Review: i enjoyed the read and i think any fan of a humorous must err use will like this give it a try
# Sentiment: ['POSITIVE']
#
# Review: i read books to make me happy laugh and generally make my day  i dont like books that make me sad
# Sentiment: ['POSITIVE']
#
# Review: was ok i read through it fairly fast do not like the cover but hey that is my own opinion
# Sentiment: ['POSITIVE']
#
# Review: not bad but not memorable a really good read makes you smile even a few days after you read it
# Sentiment: ['POSITIVE']
#
# Review: and good tittle but not much else here i bought more but got only a good title no thanks for that
# Sentiment: ['NEGATIVE']
#
# Review: i thoroughly enjoyed reading the book called two sighted it was a very easy read and a lot of fun
# Sentiment: ['POSITIVE']
#
# Review: i did not order or read this book  it is nothing i would spend my money for or read
# Sentiment: ['NEGATIVE']
#
# Review: i wsih there was more to the story than what was given but hey its a novella gotta get more
# Sentiment: ['NEGATIVE']
#
# Review: never read it because i thought it was a different author  still have may read some day
# Sentiment: ['NEGATIVE']
#
# Review: a fun read like all of her books  a book to read straight through and not put down until finished
# Sentiment: ['POSITIVE']
#
# Review: love it
# Sentiment: ['POSITIVE']
#
# Review: loved it could not put it down read this book in two days i loved it its a must read
# Sentiment: ['POSITIVE']
#
# Review: it was a total waste of my reading pleasure and a total waste of the writers time in writing it
# Sentiment: ['NEGATIVE']
#
# Review: this author is truly gifted with the pen  this book kept me riveted and it was hard to put down
# Sentiment: ['POSITIVE']
#
# Review: i did not care for this ebook i did not finish reading this ebook it went at a slow pace
# Sentiment: ['NEGATIVE']
#
# Review: this is one awesome book i will keep this one to use dailyread it if you are wounded or broken
# Sentiment: ['POSITIVE']
#
# Review: this book was not very good because the drawings were bad and i did not like this nook very much
# Sentiment: ['NEGATIVE']
#
# Review: what can you say he is a good author and the books all came as expected fill the remaining words
# Sentiment: ['POSITIVE']
#
# Review: not to bad but i expected a little more
# Sentiment: ['NEGATIVE']
#
# Review: good series the paperback has all 3 in one book be aware different on kindle
# Sentiment: ['POSITIVE']
#
# Review: it was a awful book it was  really boring i didnt like it at all it didnt have a story line
# Sentiment: ['NEGATIVE']
#
# Review: loved the story line it was a great book the only problem i have with it was it was just to short
# Sentiment: ['POSITIVE']
#
# Review: its not the worse but it had a childish feel  maybe im too picky but nothing i would recommend
# Sentiment: ['NEGATIVE']
#
# Review: i had read a similar book years ago by a different author and felt this was more or less a copycat
# Sentiment: ['NEGATIVE']
#
# Review: fun read sexy book its an easy book to read the characters were enjoyable and fun to get to know
# Sentiment: ['POSITIVE']
#
# Review: am not a reader of fantasy and thought i would give it a shot  now i know this genre is not for me
# Sentiment: ['NEGATIVE']
#
# Review: i enjoyed this series author did a decent job of keeping my interest hay hay hay hay hay hay hay
# Sentiment: ['POSITIVE']
#
# Review: it was a very good storyline and great book give it a go you wont regret it at all fab
# Sentiment: ['POSITIVE']
#
# Review: highly recommend great price enjoyable story line with  a few tears here and there
# Sentiment: ['POSITIVE']
#
# Review: i was not expecting what this book had to offer this book was just not for me was well written
# Sentiment: ['NEGATIVE']
#
# Review: long winded but  a good  book
# Sentiment: ['POSITIVE']
#
# Review: it was one of the best books that i have read in a long time  i definitely recommend it
# Sentiment: ['POSITIVE']
#
# Review: i do not like this one please remove it from my library  thanks cj
# Sentiment: ['NEGATIVE']
#
# Review: an enjoyable read i bought into the setting and had a thoroughly good time with this book
# Sentiment: ['POSITIVE']
#
# Review: quick dirty and too the point some days you just need that sort of read
# Sentiment: ['NEGATIVE']
#
# Review: always love this series and jcps writing is spectacular
# Sentiment: ['POSITIVE']
#
# Review: the ending was a little more drawn out than needed but over all it was an exciting series the end
# Sentiment: ['POSITIVE']
#
# Review: just a table of contents and index  no actual stories so it wasnt what i was looking for at all
# Sentiment: ['NEGATIVE']
#
# Review: good reading bit slow but gets interesting so then u cant put it down need to find out who did it
# Sentiment: ['NEGATIVE']
#
# Review: it was a cute story i am always a sucker for second chances in love nice rainy afternoon read
# Sentiment: ['POSITIVE']
#
# Review: not very well written and unrealistic
# Sentiment: ['NEGATIVE']
#
# Review: i am not real sure about this book just seemed weird from the get go glad it was 99 cents
# Sentiment: ['NEGATIVE']
#
# Review: not agatha christienot ms marplebut a good try
# Sentiment: ['NEGATIVE']
#
# Review: the burroughs series is a classic and it was a genuine joy to read it in ebook format
# Sentiment: ['POSITIVE']
#
# Review: i enjoyed this book
# Sentiment: ['POSITIVE']
#
# Review: book is to short waste of time just when it starts to get good it ends
# Sentiment: ['NEGATIVE']
#
# Review: just like i said it was okay and entertaining to read it at least so popular papa philip die da
# Sentiment: ['POSITIVE']
#
# Review: very cool
# Sentiment: ['POSITIVE']
#
# Review: this book has been written it such a way that it has me intrigued  eager to read the next one
# Sentiment: ['POSITIVE']
#
# Review: it was a good read but they way it ended kind of sucked it would of been nice if it was longer
# Sentiment: ['NEGATIVE']
#
# Review: i did not like this book very much i am not really into a bunch of short stories all in one book
# Sentiment: ['NEGATIVE']
#
# Review: the book was very good just not long enough love her books and have not read one i did not like
# Sentiment: ['POSITIVE']
#
# Review: not much there as far as plot or characters mild sex romance for a quick escape
# Sentiment: ['NEGATIVE']
#
# Review: i just bought my kindle fire and this was the first book i purchasedit was a good readi liked it
# Sentiment: ['POSITIVE']
#
# Review: the book had a good story but it didnt seem like it had a ending
# Sentiment: ['NEGATIVE']
#
# Review: cute yet excitingwould of liked morevicki took no time to seduce her new tenanti loved it totally
# Sentiment: ['POSITIVE']
#
# Review: ok not really interesting to me but ok read a a aa  a a done done done done done do
# Sentiment: ['NEGATIVE']
#
# Review: this was not worth the 099 it is a short story it is very predictable and not good at all
# Sentiment: ['NEGATIVE']
#
# Review: short obviously belongs with another book in a series and unbelievable  our baby what a crock
# Sentiment: ['NEGATIVE']
#
# Review: the art was no as amazing as everyone ratedthe idea of the story is decievinhand plot is really bad
# Sentiment: ['NEGATIVE']
#
# Review: i liked that the h stuck to his gun and was serious about getting back with his wife  worth it
# Sentiment: ['POSITIVE']
#
# Review: so hated this book not my cup of tea amistake to get very nasty i do not talk alot nasty
# Sentiment: ['NEGATIVE']
#
# Review: true to my word it was good to the end of the book  kept you guessing what would happen next
# Sentiment: ['POSITIVE']
#
# Review: i wish it was more it left me high and dry i was yearning for more and a better ending
# Sentiment: ['NEGATIVE']
#
# Review: i enjoyed the book  i liked the plot and ialso liked the characters  it was a good and easy read
# Sentiment: ['POSITIVE']
#
# Review: did not cut it maybe i dont like the way mr hewson writesnot enough to peak my interest sorry
# Sentiment: ['NEGATIVE']
#
# Review: a very unique approach to the idea of cooking and perfectly formatted for the kindle  its great
# Sentiment: ['POSITIVE']
#
# Review: i love it when i reread books iread as a kid and as an adult i can appreciate it even more
# Sentiment: ['POSITIVE']
#
# Review: this is a great book on the insight of  life in the first generation of tanks of world war one
# Sentiment: ['POSITIVE']
#
# Review: the story was short  i did not like the hero or he heroine  it was not worth the time or money
# Sentiment: ['NEGATIVE']
#
# Review: love it wonderful romance book thrilling to the very end one of the best books i have read ever ever
# Sentiment: ['POSITIVE']
#
# Review: i loved this book wished it hadnt be so short  i plan to keep this one  read it again
# Sentiment: ['POSITIVE']
#
# Review: this book wasnt very long but very good  great book to spend a few hours on the couch with
# Sentiment: ['POSITIVE']
#
# Review: the story line was ok  i wish that it was longer  just as you got into the story the book ended
# Sentiment: ['POSITIVE']
#
# Review: hehehe this book for me was crazy but in a good way intense i loved it great read
# Sentiment: ['POSITIVE']
#
# Review: i had a few chuckles here and there in the book kind of does remind me of how dads are everyday
# Sentiment: ['POSITIVE']
#
# Review: i love the book it left me wanting more i was wishing the story was longer but it was very good
# Sentiment: ['POSITIVE']
#
# Review: love this author i have read most of her books  and once again she doesnt disappoint
# Sentiment: ['POSITIVE']
#
# Review: this book was not bad i like the storyline  the sex was not that grate and was not much in it
# Sentiment: ['NEGATIVE']
#
# Review: this is part of a series i read and i loved the whole series i also have some on kindle
# Sentiment: ['POSITIVE']
#
# Review: finally a texas newspaper in kindle formatway to go amazon
# Sentiment: ['NEGATIVE']
#
# Review: tj and jon are very hot in this book  christine finds love and pleasure she did not no exsited
# Sentiment: ['POSITIVE']

# %%
data["transformer_sentiment_label"] = transformer_labels
data.head()
# Out:
#    index                                         reviewText  rating  \
# 0  11494  Clean and funny. A bit busy with all the diffe...       3
# 1    984  Alex a sexy hot cop and the PhD candidate. Wha...       4
# 2   1463  Good thing that this is a free story. I read i...       1
# 3  10342  Action, action, action! Equipment keeps gettin...       4
# 4   5256  this was hands down the worse book i have ever...       1
#
#                                   reviewText_cleaned  vader_sentiment  \
# 0  clean and funny a bit busy with all the differ...           0.7684
# 1  alex a sexy hot cop and the phd candidate what...           0.9325
# 2  good thing that this is a free story i read it...           0.6740
# 3  action action action equipment keeps getting b...           0.6652
# 4  this was hands down the worse book i have ever...          -0.4767
#
#   vader_sentiment_label transformer_sentiment_label
# 0              positive                  [POSITIVE]
# 1              positive                  [POSITIVE]
# 2              positive                  [NEGATIVE]
# 3              positive                  [NEGATIVE]
# 4              negative                  [NEGATIVE]

# %%
data["transformer_sentiment_label"].value_counts().plot.bar(title="Transformer Sentiment Distribution")
# Out:
# <Axes: title={'center': 'Transformer Sentiment Distribution'}, xlabel='transformer_sentiment_label'>
